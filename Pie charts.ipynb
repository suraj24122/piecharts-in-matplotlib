# %%
# pie charts in matplotlib
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
#basic pie chart example
labels = ["sachin", "sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]

plt.title("Career runs of indian batsmen")
plt.pie(runs, labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b81ba098e0>,
#   <matplotlib.patches.Wedge at 0x2b81a1bb2f0>,
#   <matplotlib.patches.Wedge at 0x2b81ba09e80>,
#   <matplotlib.patches.Wedge at 0x2b81ba0a2d0>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
# custom colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(runs, labels = labels, colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b81bab0b30>,
#   <matplotlib.patches.Wedge at 0x2b81ba41280>,
#   <matplotlib.patches.Wedge at 0x2b81bab1160>,
#   <matplotlib.patches.Wedge at 0x2b81bab1490>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
# adding edges and style slices with wedgeprops
plt.pie(
       runs, 
       labels = labels, 
       colors = colors,
       wedgeprops = {'edgecolor': 'black',
                    'linewidth':2, 'linestyle': '--'}
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x2b81baef860>,
#   <matplotlib.patches.Wedge at 0x2b81ba0a780>,
#   <matplotlib.patches.Wedge at 0x2b81baefef0>,
#   <matplotlib.patches.Wedge at 0x2b81c1b0290>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
# highlight and slice the pie chart using explode
explode = [0.1, 0, 0, 0] # only highlight sachin's slice
plt.pie(runs, labels = labels, explode = explode, colors = colors)
plt.title("Exploded pie example")
# Out:
# Text(0.5, 1.0, 'Exploded pie example')

# %%
# Adding shadows for 3D look
plt.pie(runs,
       labels = labels,
       explode = explode,
       colors = colors,
       shadow = True
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x2b81c238f80>,
#   <matplotlib.patches.Wedge at 0x2b81c238ec0>,
#   <matplotlib.patches.Wedge at 0x2b81c2395e0>,
#   <matplotlib.patches.Wedge at 0x2b81c239b80>],
#  [Text(0.44543666795344244, 1.1142648584795876, 'sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
# using startangle to rotate the pie for better alignment
plt.pie(
    runs, 
    labels = labels,
    explode = explode,
    colors = colors,
    shadow = True,
    startangle = 140
)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b81d2bc050>,
#   <matplotlib.patches.Wedge at 0x2b81c273f50>,
#   <matplotlib.patches.Wedge at 0x2b81d2bc890>,
#   <matplotlib.patches.Wedge at 0x2b81d2bcec0>],
#  [Text(-1.0574599291869724, -0.5672552319405118, 'sachin'),
#   Text(0.6579547044231889, -0.881530264328681, 'sehwag'),
#   Text(1.01607399965243, 0.42141858908965296, 'Kohli'),
#   Text(-0.2661141750968186, 1.0673252764797336, 'Yuvraj')])

# %%
# show percentages with autopct
plt.pie(
    runs, 
    labels = labels,
    autopct = '%1.1f%%',
    startangle = 140
)
plt.title("Career Run Share")
# Out:
# Text(0.5, 1.0, 'Career Run Share')

# %%
# crowded pie chart - we should avoid
# Too many categories
languages = ['Python', 'Java', 'C++', 'JavaScript', 'C#', 'Ruby', 'Go', 'Rust', 'Swift', 'PHP']
usage = [30, 20, 10, 10, 7, 5, 4, 3, 2, 1]

plt.pie(usage, labels=languages, autopct='%1.1f%%', startangle=90)
plt.title("Programming Language Usage (Crowded Example)")
plt.show()
